# %% [markdown]
# <a href="https://colab.research.google.com/github/RISHIEDABOYINA/ADM-Lab/blob/main/Lab_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
import pandas as pd

df = pd.read_csv('/content/salary_data.csv')
print (df.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# #Generate a Sample Dataset

# %%
X = np.linspace(0, 10, 50).reshape(-1, 1)
y = 2 + 3 * X - 0.5 * X**2 + np.random.normal(0, 1, X.shape)

# %% [markdown]
# #Transform Features to Polynomial Features

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %% [markdown]
# #Train a Linear Regression Model

# %%
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# #Make Predictions

# %%
y_pred = model.predict(X_poly)

# %% [markdown]
# #Evaluate Model Performance

# %%
mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.8456495451852724

# %% [markdown]
# #Calculates the Mean Squared Error (MSE) to measure the model’s accuracy.

# %%
plt.scatter(X, y, color='blue', label="Original Data")
plt.plot(X, y_pred, color='red', label="Polynomial Regression Line")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()
